# %%
import matplotlib as mpl
from matplotlib import pylab as plt
import pandas as pd
import numpy as np
from collections import defaultdict
import itertools as it
from datetime import datetime
import networkx as nx
font='AR PL KaitiM Big5'
mpl.rcParams['font.sans-serif'] = font

from IPython.display import HTML
from markdown import markdown
import csv
# %matplotlib inline
#from mpld3 import enable_notebook, disable_notebook
#enable_notebook()
#mpl.rcParams['figure.figsize'] = 12, 9

import seaborn as sns
sns.set(font=font)
sns.set_context('poster')
size_poster = mpl.rcParams['figure.figsize']
mpl.rcParams['figure.figsize'] = 16, 12

execfile('nbutils.py')
# Out:
#   File "nbutils.py", line 6
#     markdown_str = u''.join(markdown_str)
#                ^
# IndentationError: expected an indented block

# %%
execfile('utils.py')
execfile('work.py')

cn.collection_names()
# Out:
# [u'system.indexes', u'nations', u'edges', u'nodenations', u'nodes']

# %%
r = cn.edges.find_one()
dicprint(r)
print '\n'

dicprint(cn.nodes.find_one())

cols = r.keys()
cols.remove('_id')
cols.remove('Unique_ID')
print '\nTotal Collections:'
sprint(cols)
# Out:
#  linkType	EO
#  direction	1
#  chinesePos	助理秘书
#  date_from
#  Entity_ID2	124901
#  date_to
#  description_	Assistant Secretary
#  Entity_ID1	102767
#  _id	53e63d3387f44612c71e9f4c
#  Unique_ID	171253
#
#
#  status
#  desc_jurisdiction
#  subtypes_	OFFICER
#  juris
#  desc_status
#  tax_stat_description
#  tax_stat
#  desc_company_type
#  completeAddresses
#  searchField_	Bisbro Investment Company Ltd.
#  dorm_dat
#  Description_	Bisbro Investment Company Ltd.
#  inc_dat
#  _id	53e63ec787f44612c72c2cf0
#  type
#  Unique_ID	51113
#  agencyID	1
#
# Total Collections:
#  linkType	direction	chinesePos	date_from	Entity_ID2	date_to	description_	Entity_ID1

# %%
dicprint(cn.edges.find_one())

#del(df)
df=getdf(cn.edges.find())
del(df['_id'], df['Unique_ID'])
df1 = df.describe().T
# Out:
#  linkType	EO
#  direction	1
#  chinesePos	助理秘书
#  date_from
#  Entity_ID2	124901
#  date_to
#  description_	Assistant Secretary
#  Entity_ID1	102767
#  _id	53e63d3387f44612c71e9f4c
#  Unique_ID	171253

# %%
dicprint(cn.nodes.find_one())

#del(df)
df=getdf(cn.nodes.find())
del(df['_id'], df['Unique_ID'])
df1 = df.describe().T
# Out:
#  status
#  desc_jurisdiction
#  subtypes_	OFFICER
#  juris
#  desc_status
#  tax_stat_description
#  tax_stat
#  desc_company_type
#  completeAddresses
#  searchField_	Bisbro Investment Company Ltd.
#  dorm_dat
#  Description_	Bisbro Investment Company Ltd.
#  inc_dat
#  _id	53e63ec787f44612c72c2cf0
#  type
#  Unique_ID	51113
#  agencyID	1
#                        count  unique        top    freq
# Description_          278693  255939   Bearer 1    2653
# agencyID              278693       3          1  144312
# completeAddresses     278693    1977             192943
# desc_company_type     278693      56             175466
# desc_jurisdiction     278693      28             226274
# desc_status           278693      22             182218
# dorm_dat              278693     276             258486
# inc_dat               278693    4869             182556
# juris                 278693      33             226274
# searchField_          278693  258196  Bearer 1     2653
# ...

# %%
# Out:
#   agencyID
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
